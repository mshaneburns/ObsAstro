# %% [markdown]
# # CCD data reduction
# We must install `ccdproc` with the following command
# ```
# % conda install -c conda-forge ccdproc
# ```
#
# To align images can install `astroalign`
# ```
# % conda install -c conda-forge astroalign
# ```
#
# To use `photutils`
# ```
# % conda install -c conda-forge photutils
# ```

# %%
import numpy as np
from astropy.nddata import CCDData
import ccdproc
import matplotlib.pyplot as plt
#from astropy.visualization import astropy_mpl_style
plt.style.use('/Users/sburns/lib/python/im_disp.mplstyle')

# %%
ccd = CCDData.read('images/M51_R_p.fits')

# %%
plt.imshow(ccd,cmap='gray',vmin=50,vmax=250)
